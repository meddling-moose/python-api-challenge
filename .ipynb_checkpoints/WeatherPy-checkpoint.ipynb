# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}appid={weather_api_key}&q={city}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dudinka
# Processing Record 2 of Set 1 | sinop
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | hawaiian paradise park
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | luorong
# Processing Record 7 of Set 1 | utrik
# Processing Record 8 of Set 1 | saint-francois
# Processing Record 9 of Set 1 | chonchi
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | caleta de carquin
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 16 of Set 1 | moratuwa
# Processing Record 17 of Set 1 | trinidad
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | anadyr
# Processing Record 20 of Set 1 | gamba
# Processing Record 21 of Set 1 | grantsville
# Processing Record 22 of Set 1 | udachny
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | stanley
# Processing Record 26 of Set 1 | la passe
# Processing Record 27 of Set 1 | papatowai
# Processing Record 28 of Set 1 | ust-nera
# Processing Record 29 of Set 1 | tromso
# Processing Record 30 of Set 1 | porbandar
# Processing Record 31 of Set 1 | isafjordur
# Processing Record 32 of Set 1 | whitehorse
# Processing Record 33 of Set 1 | amungan
# Processing Record 34 of Set 1 | mont-laurier
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | bamboo flat
# Processing Record 37 of Set 1 | qaqortoq
# Processing Record 38 of Set 1 | grytviken
# Processing Record 39 of Set 1 | shenjiamen
# Processing Record 40 of Set 1 | kuanda
# Processing Record 41 of Set 1 | ta`u
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | kapuskasing
# Processing Record 44 of Set 1 | barrow in furness
# Processing Record 45 of Set 1 | kalemie
# Processing Record 46 of Set 1 | cockburn town
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | kalaleh
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | callao
# Processing Record 0 of Set 2 | iskateley
# Processing Record 1 of Set 2 | sanya
# Processing Record 2 of Set 2 | adamstown
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | rahimatpur
# Processing Record 5 of Set 2 | mejit
# Processing Record 6 of Set 2 | edinburgh of the seven seas
# Processing Record 7 of Set 2 | redencao
# Processing Record 8 of Set 2 | embi
# Processing Record 9 of Set 2 | mossel bay
# Processing Record 10 of Set 2 | dolinsk
# Processing Record 11 of Set 2 | osorno
# Processing Record 12 of Set 2 | nova sintra
# Processing Record 13 of Set 2 | blackmans bay
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | kirensk
# Processing Record 17 of Set 2 | timbuktu
# Processing Record 18 of Set 2 | palu
# Processing Record 19 of Set 2 | port mathurin
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | nar'yan-mar
# Processing Record 22 of Set 2 | saint-pierre
# Processing Record 23 of Set 2 | portland
# Processing Record 24 of Set 2 | boa vista
# Processing Record 25 of Set 2 | aasiaat
# Processing Record 26 of Set 2 | talnakh
# Processing Record 27 of Set 2 | ugoofaaru
# Processing Record 28 of Set 2 | sopron
# Processing Record 29 of Set 2 | fisterra
# Processing Record 30 of Set 2 | badger
# Processing Record 31 of Set 2 | tougue
# Processing Record 32 of Set 2 | ocean city
# Processing Record 33 of Set 2 | fale old settlement
# Processing Record 34 of Set 2 | lihue
# Processing Record 35 of Set 2 | margate
# Processing Record 36 of Set 2 | pisco
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | melfi
# Processing Record 41 of Set 2 | vorkuta
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | margaret river
# Processing Record 45 of Set 2 | alice springs
# Processing Record 46 of Set 2 | labrador city
# Processing Record 47 of Set 2 | uige
# Processing Record 48 of Set 2 | polyarnyy
# Processing Record 49 of Set 2 | argo
# Processing Record 0 of Set 3 | college
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | vorgashor
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | novodvinsk
# Processing Record 5 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 3 | fort mcmurray
# Processing Record 7 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 3 | naze
# Processing Record 9 of Set 3 | kapa'a
# Processing Record 10 of Set 3 | karlshamn
# Processing Record 11 of Set 3 | wailua homesteads
# Processing Record 12 of Set 3 | la cocha
# Processing Record 13 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set
of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 42 of Set 4 | bardai
# Processing Record 43 of Set 4 | nyuzen
# Processing Record 44 of Set 4 | bubaque
# Processing Record 45 of Set 4 | pontianak
# Processing Record 46 of Set 4 | james island
# City not found. Skipping...
# Processing Record 47 of Set 4 | sur
# Processing Record 48 of Set 4 | atmore
# Processing Record 49 of Set 4 | pattani
# Processing Record 0 of Set 5 | haiku-pauwela
# Processing Record 1 of Set 5 | antibes
# Processing Record 2 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 5 | talara
# Processing Record 4 of Set 5 | saint-felicien
# Processing Record 5 of Set 5 | lagos
# Processing Record 6 of Set 5 | malango
# Processing Record 7 of Set 5 | georgetown
# Processing Record 8 of Set 5 | amol
# Processing Record 9 of Set 5 | mumford
# Processing Record 10 of Set 5 | changji
# Processing Record 11 of Set 5 | san fernando
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | kassala
# Processing Record 14 of Set 5 | cruzeiro do sul
# Processing Record 15 of Set 5 | balykshi
# Processing Record 16 of Set 5 | arzgir
# Processing Record 17 of Set 5 | ouro preto do oeste
# Processing Record 18 of Set 5 | afaahiti
# Processing Record 19 of Set 5 | jose maria morelos
# Processing Record 20 of Set 5 | levuka
# Processing Record 21 of Set 5 | rahuri
# Processing Record 22 of Set 5 | beipiao
# Processing Record 23 of Set 5 | rasht
# Processing Record 24 of Set 5 | miyako
# Processing Record 25 of Set 5 | touros
# Processing Record 26 of Set 5 | illizi
# Processing Record 27 of Set 5 | korsholm
# Processing Record 28 of Set 5 | sychevka
# Processing Record 29 of Set 5 | tulalip
# Processing Record 30 of Set 5 | severo-yeniseyskiy
# Processing Record 31 of Set 5 | tidjikja
# Processing Record 32 of Set 5 | arraial do cabo
# Processing Record 33 of Set 5 | dalandzadgad
# Processing Record 34 of Set 5 | paysandu
# Processing Record 35 of Set 5 | flying fish cove
# Processing Record 36 of Set 5 | laojunmiao
# Processing Record 37 of Set 5 | santa rosa
# Processing Record 38 of Set 5 | barra de santo antonio
# Processing Record 39 of Set 5 | san patricio
# Processing Record 40 of Set 5 | inarajan village
# Processing Record 41 of Set 5 | nemuro
# Processing Record 42 of Set 5 | st. john's
# Processing Record 43 of Set 5 | nyurba
# Processing Record 44 of Set 5 | marudi
# City not found. Skipping...
# Processing Record 45 of Set 5 | olyokminsk
# Processing Record 46 of Set 5 | fada
# Processing Record 47 of Set 5 | vila velha
# Processing Record 48 of Set 5 | aglona
# Processing Record 49 of Set 5 | tralee
# Processing Record 0 of Set 6 | cuyo
# Processing Record 1 of Set 6 | shaowu
# Processing Record 2 of Set 6 | xiahu
# Processing Record 3 of Set 6 | porto novo
# Processing Record 4 of Set 6 | christchurch
# Processing Record 5 of Set 6 | cam ranh
# Processing Record 6 of Set 6 | murun-kuren
# Processing Record 7 of Set 6 | sarangani
# Processing Record 8 of Set 6 | warman
# Processing Record 9 of Set 6 | revda
# Processing Record 10 of Set 6 | lazaro cardenas
# Processing Record 11 of Set 6 | east london
# Processing Record 12 of Set 6 | janze
# Processing Record 13 of Set 6 | saint leonards-on-sea
# City not found. Skipping...
# Processing Record 14 of Set 6 | mirny
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | el alto
# Processing Record 17 of Set 6 | puerto lempira
# Processing Record 18 of Set 6 | bamyan
# Processing Record 19 of Set 6 | pale
# Processing Record 20 of Set 6 | gravina in puglia
# Processing Record 21 of Set 6 | cartagena
# Processing Record 22 of Set 6 | nogliki
# Processing Record 23 of Set 6 | dzilam gonzalez
# Processing Record 24 of Set 6 | jaffna
# Processing Record 25 of Set 6 | olds
# Processing Record 26 of Set 6 | puerto armuelles
# Processing Record 27 of Set 6 | cadale
# Processing Record 28 of Set 6 | mili
# Processing Record 29 of Set 6 | middelburg
# Processing Record 30 of Set 6 | pacific grove
# Processing Record 31 of Set 6 | kenora
# Processing Record 32 of Set 6 | richards bay
# Processing Record 33 of Set 6 | lata
# Processing Record 34 of Set 6 | la grande
# Processing Record 35 of Set 6 | dakhla
# Processing Record 36 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 37 of Set 6 | pimentel
# Processing Record 38 of Set 6 | dryden
# Processing Record 39 of Set 6 | peniche
# Processing Record 40 of Set 6 | acarau
# Processing Record 41 of Set 6 | poshekhon'ye
# Processing Record 42 of Set 6 | mount gambier
# Processing Record 43 of Set 6 | mahdia
# Processing Record 44 of Set 6 | usogorsk
# Processing Record 45 of Set 6 | kolwezi
# Processing Record 46 of Set 6 | el haouaria
# Processing Record 47 of Set 6 | urangan
# Processing Record 48 of Set 6 | jayapura
# Processing Record 49 of Set 6 | hamilton
# Processing Record 0 of Set 7 | vikhorevka
# Processing Record 1 of Set 7 | brownwood
# Processing Record 2 of Set 7 | bayanhongor
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | argostolion
# Processing Record 5 of Set 7 | klyuchi
# Processing Record 6 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 8 of Set 7 | ngong
# Processing Record 9 of Set 7 | saint john
# Processing Record 10 of Set 7 | carutapera
# Processing Record 11 of Set 7 | mariinsk
# Processing Record 12 of Set 7 | chokwe
# Processing Record 13 of Set 7 | beau vallon
# Processing Record 14 of Set 7 | panaba
# Processing Record 15 of Set 7 | tazacorte
# Processing Record 16 of Set 7 | port alfred
# Processing Record 17 of Set 7 | port lincoln
# Processing Record 18 of Set 7 | xilin hot
# Processing Record 19 of Set 7 | kurayoshi
# Processing Record 20 of Set 7 | tahe
# Processing Record 21 of Set 7 | kili
# Processing Record 22 of Set 7 | brokopondo
# Processing Record 23 of Set 7 | kayangel
# Processing Record 24 of Set 7 | coquimbo
# Processing Record 25 of Set 7 | araripina
# Processing Record 26 of Set 7 | babor - ville
# Processing Record 27 of Set 7 | hithadhoo
# Processing Record 28 of Set 7 | el calafate
# Processing Record 29 of Set 7 | chegdomyn
# Processing Record 30 of Set 7 | billiri
# Processing Record 31 of Set 7 | benguela
# Processing Record 32 of Set 7 | paciran
# Processing Record 33 of Set 7 | el nido
# Processing Record 34 of Set 7 | big bend
# Processing Record 35 of Set 7 | chowchilla
# Processing Record 36 of Set 7 | mpongwe
# Processing Record 37 of Set 7 | bengkulu
# Processing Record 38 of Set 7 | namtsy
# Processing Record 39 of Set 7 | morondava
# Processing Record 40 of Set 7 | iraquara
# Processing Record 41 of Set 7 | pandan
# Processing Record 42 of Set 7 | ust'-ilimsk
# Processing Record 43 of Set 7 | santana
# Processing Record 44 of Set 7 | mando
# Processing Record 45 of Set 7 | mount isa
# Processing Record 46 of Set 7 | ujae
# Processing Record 47 of Set 7 | khanty-mansiysk
# Processing Record 48 of Set 7 | manta
# Processing Record 49 of Set 7 | peace river
# Processing Record 0 of Set 8 | altay
# Processing Record 1 of Set 8 | sambava
# Processing Record 2 of Set 8 | faya-largeau
# Processing Record 3 of Set 8 | shahabad
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 
# Processing Record 27 of Set 9 | taoudenni
# Processing Record 28 of Set 9 | recani
# Processing Record 29 of Set 9 | newman
# Processing Record 30 of Set 9 | mugia
# Processing Record 31 of Set 9 | malanje
# Processing Record 32 of Set 9 | antofagasta
# Processing Record 33 of Set 9 | fort bragg
# Processing Record 34 of Set 9 | kingston
# Processing Record 35 of Set 9 | hammerfest
# Processing Record 36 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 37 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 9 | kenai
# Processing Record 39 of Set 9 | uaboe
# City not found. Skipping...
# Processing Record 40 of Set 9 | bloomfield
# Processing Record 41 of Set 9 | machico
# Processing Record 42 of Set 9 | limon
# Processing Record 43 of Set 9 | bela vista
# Processing Record 44 of Set 9 | hargeysa
# Processing Record 45 of Set 9 | sandnessjoen
# Processing Record 46 of Set 9 | camocim
# Processing Record 47 of Set 9 | horsham
# Processing Record 48 of Set 9 | rhinelander
# Processing Record 49 of Set 9 | baker city
# Processing Record 0 of Set 10 | roscrea
# Processing Record 1 of Set 10 | kangding
# Processing Record 2 of Set 10 | tamanrasset
# Processing Record 3 of Set 10 | kerikeri
# Processing Record 4 of Set 10 | globe
# City not found. Skipping...
# Processing Record 5 of Set 10 | anloga
# Processing Record 6 of Set 10 | baruun-urt
# Processing Record 7 of Set 10 | belyy yar
# Processing Record 8 of Set 10 | vorsma
# Processing Record 9 of Set 10 | kegeyli shahar
# Processing Record 10 of Set 10 | san lawrenz
# Processing Record 11 of Set 10 | matiri
# Processing Record 12 of Set 10 | khamis mushait
# Processing Record 13 of Set 10 | isiro
# Processing Record 14 of Set 10 | nantucket
# Processing Record 15 of Set 10 | puerto deseado
# Processing Record 16 of Set 10 | young
# Processing Record 17 of Set 10 | baykal'sk
# Processing Record 18 of Set 10 | jinan
# Processing Record 19 of Set 10 | ndola
# Processing Record 20 of Set 10 | magadan
# Processing Record 21 of Set 10 | molde
# Processing Record 22 of Set 10 | goz beida
# Processing Record 23 of Set 10 | prado
# Processing Record 24 of Set 10 | nabire
# Processing Record 25 of Set 10 | ambodivoara
# City not found. Skipping...
# Processing Record 26 of Set 10 | nadym
# Processing Record 27 of Set 10 | al ghayzah
# Processing Record 28 of Set 10 | morehead
# Processing Record 29 of Set 10 | fort st. john
# Processing Record 30 of Set 10 | bechar
# Processing Record 31 of Set 10 | abu 'arish
# City not found. Skipping...
# Processing Record 32 of Set 10 | kondopoga
# Processing Record 33 of Set 10 | kismayo
# Processing Record 34 of Set 10 | murghob
# Processing Record 35 of Set 10 | kushiro
# Processing Record 36 of Set 10 | ayaviri
# Processing Record 37 of Set 10 | ambato
# Processing Record 38 of Set 10 | amga
# Processing Record 39 of Set 10 | francistown
# Processing Record 40 of Set 10 | cambria
# Processing Record 41 of Set 10 | ponta delgada
# Processing Record 42 of Set 10 | holualoa
# Processing Record 43 of Set 10 | minas de marcona
# Processing Record 44 of Set 10 | kavieng
# Processing Record 45 of Set 10 | broome
# Processing Record 46 of Set 10 | pemangkat
# Processing Record 47 of Set 10 | kavaratti
# Processing Record 48 of Set 10 | tual
# Processing Record 49 of Set 10 | vilyuchinsk
# Processing Record 0 of Set 11 | al bawiti
# Processing Record 1 of Set 11 | rabigh
# Processing Record 2 of Set 11 | lascano
# Processing Record 3 of Set 11 | uturoa
# Processing Record 4 of Set 11 | santa cruz
# Processing Record 5 of Set 11 | newport beach
# Processing Record 6 of Set 11 | gaiman
# Processing Record 7 of Set 11 | karratha
# Processing Record 8 of Set 11 | okola
# Processing Record 9 of Set 11 | saint-philippe
# Processing Record 10 of Set 11 | arsk
# Processing Record 11 of Set 11 | zhaotong
# Processing Record 12 of Set 11 | byron bay
# Processing Record 13 of Set 11 | catacaos
# Processing Record 14 of Set 11 | dunedin
# Processing Record 15 of Set 11 | miyazu
# Processing Record 16 of Set 11 | korla
# Processing Record 17 of Set 11 | los osos
# Processing Record 18 of Set 11 | biltine
# Processing Record 19 of Set 11 | ishigaki
# Processing Record 20 of Set 11 | nuuk
# Processing Record 21 of Set 11 | aksu
# Processing Record 22 of Set 11 | namibe
# Processing Record 23 of Set 11 | kalaoa
# Processing Record 24 of Set 11 | salinopolis
# Processing Record 25 of Set 11 | mount pearl
# Processing Record 26 of Set 11 | gornopravdinsk
# Processing Record 27 of Set 11 | orkney
# Processing Record 28 of Set 11 | howrah
# Processing Record 29 of Set 11 | anori
# Processing Record 30 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 31 of Set 11 | fort dodge
# Processing Record 32 of Set 11 | vilhena
# Processing Record 33 of Set 11 | safotu
# Processing Record 34 of Set 11 | luganville
# Processing Record 35 of Set 11 | la romana
# Processing Record 36 of Set 11 | princeville
# Processing Record 37 of Set 11 | wenzhou
# Processing Record 38 of Set 11 | rongelap
# Processing Record 39 of Set 11 | luanda
# Processing Record 40 of Set 11 | carepa
# Processing Record 41 of Set 11 | kasongo-lunda
# Processing Record 42 of Set 11 | meadow lakes
# Processing Record 43 of Set 11 | nanakuli
# Processing Record 44 of Set 11 | mana
# Processing Record 45 of Set 11 | phalaborwa
# Processing Record 46 of Set 11 | esquel
# Processing Record 47 of Set 11 | pinheiral
# Processing Record 48 of Set 11 | bannu
# Processing Record 49 of Set 11 | sao vicente
# Processing Record 0 of Set 12 | eureka
# Processing Record 1 of Set 12 | achacachi
# Processing Record 2 of Set 12 | cascavel
# Processing Record 3 of Set 12 | chesma
# Processing Record 4 of Set 12 | ungsang-nodongjagu
# Processing Record 5 of Set 12 | al balyana
# Processing Record 6 of Set 12 | holmsund
# Processing Record 7 of Set 12 | ouallam
# Processing Record 8 of Set 12 | strezhevoy
# Processing Record 9 of Set 12 | ulladulla
# Processing Record 10 of Set 12 | selfoss
# Processing Record 11 of Set 12 | itoman
# Processing Record 12 of Set 12 | sterling
# Processing Record 13 of Set 12 | abomey
# Processing Record 14 of Set 12 | kruisfontein
# Processing Record 15 of Set 12 | barkhera kalan
# Processing Record 16 of Set 12 | konarka
# Processing Record 17 of Set 12 | bodaybo
# Processing Record 18 of Set 12 | panacan
# Processing Record 19 of Set 12 | west salem
# Processing Record 20 of Set 12 | broken hill
# Processing Record 21 of Set 12 | karasburg
# Processing Record 22 of Set 12 | luwuk
# Processing Record 23 of Set 12 | colonia
# Processing Record 24 of Set 12 | ketchikan
# Processing Record 25 of Set 12 | tutoia
# Processing Record 26 of Set 12 | botro
# Processing Record 27 of Set 12 | berdigestyakh
# Processing Record 28 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 29 of Set 12 | burao
# Processing Record 30 of Set 12 | upington
# Processing Record 31 of Set 12 | mata-utu
# Processing Record 32 of Set 12 | shahrak-e pabedana
# City not found. Skipping...
# Processing Record 33 of Set 12 | bodo
# Processing Record 34 of Set 12 | kanoya
# Processing Record 35 of Set 12 | summerfield
# Processing Record 36 of Set 12 | agadez
# Processing Record 37 of Set 12 | pangody
# Processing Record 38 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 39 of Set 12 | constitucion
# Processing Record 40 of Set 12 | morden
# Processing Record 41 of Set 12 | carauari
# Processing Record 42 of Set 12 | kargasok
# Processing Record 43 of Set 12 | sisimiut
# Processing Record 44 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 12 | brisas de zicatela
# Processing Record 46 of Set 12 | oamaru
# Processing Record 47 of Set 12 | xai-xai
# Processing Record 48 of Set 12 | ust'-kut
# Processing Record 49 of Set 12 | isangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 dudinka  69.4058   86.1778    257.97        90         100
# 1                   sinop  41.7711   34.8709    288.80        51          11
# 2       port-aux-francais -49.3500   70.2167    280.15        78         100
# 3  hawaiian paradise park  19.5933 -154.9731    297.88        84         100
# 4            longyearbyen  78.2186   15.6401    257.06        78          75
#
#    Wind Speed Country        Date
# 0        6.26      RU  1712018082
# 1        4.00      TR  1712018341
# 2        8.42      TF  1712018539
# 3        3.09      US  1712018540
# 4        1.54      SJ  1712018540

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       dudinka  69.4058   86.1778    257.97        90
# 1                         sinop  41.7711   34.8709    288.80        51
# 2             port-aux-francais -49.3500   70.2167    280.15        78
# 3        hawaiian paradise park  19.5933 -154.9731    297.88        84
# 4                  longyearbyen  78.2186   15.6401    257.06        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        6.26      RU  1712018082
# 1                11        4.00      TR  1712018341
# 2               100        8.42      TF  1712018539
# 3               100        3.09      US  1712018540
# 4                75        1.54      SJ  1712018540

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values, y_values, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitude vs. Temperature (2024-04-01)')

# Save the figure
plt.savefig("output/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values, y_values, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (2024-04-01)')

# Save the figure
plt.savefig("output/Fig2.png")
#Not sure how to make the background like graph paper

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values, y_values, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (2024-04-01)')

# Save the figure
plt.savefig("output/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values, y_values, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2024-04-01)')

# Save the figure
plt.savefig("output/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg_plot(x_values, y_values, ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.xlabel('Latitude')
    plt.ylabel(ylabel)
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
new_df = city_data_df

mask = new_df['Lat'] >= 0
northern_hemi_df = new_df[mask]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       dudinka  69.4058   86.1778    257.97        90
# 1                         sinop  41.7711   34.8709    288.80        51
# 3        hawaiian paradise park  19.5933 -154.9731    297.88        84
# 4                  longyearbyen  78.2186   15.6401    257.06        78
# 5                       luorong  24.4058  109.6086    300.86        73
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        6.26      RU  1712018082
# 1                11        4.00      TR  1712018341
# 3               100        3.09      US  1712018540
# 4                75        1.54      SJ  1712018540
# 5                21        6.76      CN  1712018298

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

mask = new_df['Lat'] < 0
southern_hemi_df = new_df[mask]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port-aux-francais -49.3500   70.2167    280.15        78         100
# 8                  chonchi -42.6128  -73.8092    284.33        87         100
# 10                waitangi -43.9535 -176.5597    287.49        82          82
# 11       caleta de carquin -11.0925  -77.6267    295.03        85         100
# 12          puerto natales -51.7236  -72.4875    280.14        91         100
#
#          Wind Speed Country        Date
# City_ID
# 2              8.42      TF  1712018539
# 8              0.92      CL  1712018541
# 10             0.45      NZ  1712018541
# 11             3.39      PE  1712018541
# 12             2.10      CL  1712018542

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Max Temp')

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (0, 260), fontsize=15, color="red")
# Out:
# The r-squared is: 0.805572794363501
# Text(0, 260, 'y = -0.59x + 307.83')

# %%
# Linear regression on Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Max Temp')

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (-55, 305), fontsize=15, color="red")
# Out:
# The r-squared is: 0.47107549183506225
# Text(-55, 305, 'y = 0.3x + 300.99')

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is an indirect relationship between latitude and max temperature, as expected. When Latitude increases the temperature drops at an average rate of -0.59 degrees per latitude increase. In the Souther hemisphere, there is a less steep, direct relationship between latitude and max temperature. When latitude increases, the max temp also increases at an average rate of 0.3 degrees per latitude increase. The relatively high r squared values for both mean that there is a strong relationship between latitude and max temp.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Humidity')

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (40, 0), fontsize=15, color="red")
# Out:
# The r-squared is: 0.04851713537281817
# Text(40, 0, 'y = 0.25x + 60.3')

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Humidity')

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (-55, 30), fontsize=15, color="red")
#Not sure why 'Text(-55, ...) is showing up
# Out:
# The r-squared is: 0.0771327061847594
# Text(-55, 30, 'y = 0.28x + 84.91')

# %% [markdown]
# **Discussion about the linear relationship:** For both the northern and southern hemisphere's data, the r value is extremely small. This means that there is not evidence of a strong relationship between latitude and humidity. This makes sense if you think about it, but is still a little curious. Both linear relationships indicate direct relationships between latitude and humidity. This would suggest that the more north you go, the more humid it gets on average.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Cloudiness')

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (40, 30), fontsize=15, color="red")
# Out:
# The r-squared is: 0.017003702983112833
# Text(40, 30, 'y = 0.27x + 48.4')

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Cloudiness')

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (-55, 30), fontsize=15, color="red")
# Out:
# The r-squared is: 0.050411578073587746
# Text(-55, 30, 'y = 0.55x + 78.81')

# %% [markdown]
# **Discussion about the linear relationship:** For both the northern and southern hemisphere's data, the r value is extremely small. This means that there is not evidence of a strong relationship between latitude and humidity. Looking at the scatter plots, it's very easy to see that there is no clear relationship. There is so much variance across the data thatit's hard to determine anything at all. That being said, the regression lines for both suggest a direct relationship between cloudiness and latitude, but the r squared value suggests low confidence.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Wind Speed')

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (0, 12), fontsize=15, color="red")
# Out:
# The r-squared is: 0.0028841656474291187
# Text(0, 12, 'y = 0.01x + 3.6')

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Wind Speed')

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (-50, 10), fontsize=15, color="red")
# Out:
# The r-squared is: 0.03607923466073227
# Text(-50, 10, 'y = -0.03x + 2.87')

# %% [markdown]
# **Discussion about the linear relationship:** Once again, there is no clear relationship between latitude and wind speed for the southern hemsisphere or the northern hemisphere. Looking at the scatterplot you can probably deduce as much. A low r squared score suggests no relationship and the points themselves have an extremely high variance.
